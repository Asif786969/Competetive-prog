# %%
import pandas as pd 
df=pd.read_csv(r'C:\Users\asif1\OneDrive\Desktop\New folder (2)\prnune.csv')
# Out:
#    Unnamed: 0         website                      Title  \
# 0           0        PervMom         Revolutionary Fuck
# 1           1  FamilyStrokes       Step Family Business
# 2           2          Vixen      A Club VXN Vacation 3
# 3           3    HijabHookup                    Haboobi
# 4           4     BangBros18    I Can’t Get Kicked Out!
#
#                                    Actors Views Likes
# 0                  Kitten Latenight, Zeus   404     0
# 1                 Harley King, Tommy Gunn   285     0
# 2     Lika Star, Mary Rock, Chris Diamond   253     0
# 3              Alexia Anders, Donnie Rock   191     0
# 4   Kira Perez, Tyler Steel, Brick Danger   166     0

# %%
Actors=df['Actors']
females=[]
for e in Actors:
    x=e.split(',')
    print(x)
    females.append(x[0][1:])
# Out:
# [' Kitten Latenight', ' Zeus']
# [' Harley King', ' Tommy Gunn']
# [' Lika Star', ' Mary Rock', ' Chris Diamond']
# [' Alexia Anders', ' Donnie Rock']
# [' Kira Perez', ' Tyler Steel', ' Brick Danger']
# [' Blake Blossom', ' Peter Green']
# [' Linda Gonzalez aka Linda Black', ' Tommy Cabrio']
# [' Lacey London', ' Filthy Rich']
# [' Paris Amour', ' Damon Dice', ' Ricky Johnson']
# [' Leda Lotharia', ' J Mac']
# [' Gia Derza', ' Xander Corvus']
# [' Kenzie Reeves', ' Lola Fae', ' J Mac']
# [' Ryan Keely', ' Kayla Kayden']
# [' Reyna De La Cruz', ' James Angel']
# [' Luna Star', ' Michael Stefano']
# [' Azul Hermosa', ' Michael Vegas']
# [' Rachel Raxxx', ' Vina Sky']
# [' Capri Lmonde', ' Christian Clay']
# [' Aften Opal', ' Jenna Starr', ' Xander Corvus']
# [' Phoenix Marie', ' Demi Sutra']
# [' Jessa Rhodes', ' Charles Dera']
# [' Liv Wild', ' Nathan Bronson']
# [' Kimber Lee']
# [' Lolly Dames', ' Layla Belle', ' Peter Green']
# [' Vivianne De Silva', ' Filthy Rich']
# ...

# %%
females=list(females)

# %%
genders=pd.DataFrame(columns=['name','gender'])
for ele in males:
    genders.loc[len(genders.index)]=[ele,'male']
    
genders
# Out:
#                               name gender
# 0                     Zachary Wild   male
# 1                      Jewels Jade   male
# 2                    Elliott Amell   male
# 3                          Ana Fox   male
# 4                   Toby aka Totti   male
# 5                      Dolly Diore   male
# 6                             Mitt   male
# 7                       Freddy Gon   male
# 8                      Azure Angel   male
# 9                     Alan Freeman   male
# 10                    Vince Carter   male
# 11                           Mugur   male
# 12                     Tegan James   male
# 13                       Tori Dean   male
# 14                            Ulan   male
# 15                   Hayli Sanders   male
# 16                            Vlad   male
# 17                   Bruno Dickemz   male
# 18                         Claudio   male
# 19                         Rachael   male
# 20                  Tristan Seagal   male
# ...

# %%
genders.to_csv(r'C:\Users\asif1\OneDrive\Desktop\New folder (2)\males.csv')

# %%
s=' apple'
s=s[1:]
print(len(s))
# Out:
# 5

# %%
males=[]
for e in Actors:
    x=e.split(',')
    for ele in x:
        new=ele[1:]
        if new not in females:
            males.append(new)
for el in males:
    print(el)
# Out:
# Zeus
# Tommy Gunn
# Chris Diamond
# Donnie Rock
# Tyler Steel
# Brick Danger
# Peter Green
# Tommy Cabrio
# Filthy Rich
# Damon Dice
# Ricky Johnson
# J Mac
# Xander Corvus
# J Mac
# James Angel
# Michael Stefano
# Michael Vegas
# Christian Clay
# Jenna Starr
# Xander Corvus
# Charles Dera
# Nathan Bronson
# Layla Belle
# Peter Green
# Filthy Rich
# Peter Green
# Brick Danger
# Filthy Rich
# Johnny The Kid
# Brick Danger
# Tyler Steel
# Charles Dera
# Tyler Nixon
# Quinton James
# Damon Dice
# Stirling Cooper
# Quinton James
# Donnie Rock
# Seth Gamble
# Seth Gamble
# Stirling Cooper
# Seth Gamble
# Brad Newman
# Johnny The Kid
# Stirling Cooper
# Donnie Rock
# Tony Profane
# Peter Green
# Chuck
# Seth Gamble
# Lucas Frost
# Jay Romero
# Logan Pierce
# Tommy Woods
# Seth Gamble
# Charles Dera
# Tyler Nixon
# Peter Green
# Preston Parker
# Jimmy Michaels
# Oliver Flynn
# Peter Green
# Ryan Madison
# Alberto Blanco
# Jack Kallahari
# Ryan Madison
# Tommy Cabrio
# Tommy Cabrio
# ...

# %%
males=list(set(males))
